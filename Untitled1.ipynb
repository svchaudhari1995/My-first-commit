# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/svchaudhari1995/My-first-commit/blob/master/Untitled1.ipynb)

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI' -O hackmove
#   wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=FILEID' -O FILENAME

# https://docs.google.com/uc?export=download&id=1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI" -O myhack && rm -rf /tmp/cookies.txt
# Out:
# --2018-08-19 10:14:21--  https://docs.google.com/uc?export=download&confirm=WrOE&id=1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI
# Resolving docs.google.com (docs.google.com)... 108.177.112.113, 108.177.112.101, 108.177.112.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.112.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/95tdhu8tj97grom9bed8ra8gkavhefjn/1534672800000/17226435966834450280/*/1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI?e=download [following]
# ...
# --2018-08-19 10:14:21--  https://doc-08-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/95tdhu8tj97grom9bed8ra8gkavhefjn/1534672800000/17226435966834450280/*/1-Y8brWA6_Hj8WuY01FtKAJG3ln_quRWI?e=download
# Resolving doc-08-8c-docs.googleusercontent.com (doc-08-8c-docs.googleusercontent.com)... 108.177.112.132, 2607:f8b0:4001:c12::84
# ...

# %%
# !ls
# Out:
# datalab  myhack  sample_data

# %%
import os
os.chdir("myhack")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-54-d9384b67cf93> in <module>()
#       1 import os
# ----> 2 os.chdir("myhack")
#
# NotADirectoryError: [Errno 20] Not a directory: 'myhack'

# %%
# !unzip myhack
# Out:
# Archive:  myhack
#    creating: airs-master/
#   inflating: airs-master/.gitignore
#    creating: airs-master/.ipynb_checkpoints/
#   inflating: airs-master/.ipynb_checkpoints/checkfiles-checkpoint.ipynb
#   inflating: airs-master/.ipynb_checkpoints/train_nb-checkpoint.ipynb
#    creating: airs-master/airs-dataset/
#    creating: airs-master/airs-dataset/test-input/
#   inflating: airs-master/airs-dataset/test-input/10228690_15.tiff
#   inflating: airs-master/airs-dataset/test-input/10978735_15.tiff
#   inflating: airs-master/airs-dataset/test-input/10978795_15.tiff
#   inflating: airs-master/airs-dataset/test-input/18028945_15.tiff
#   inflating: airs-master/airs-dataset/test-input/21929020_15.tiff
#   inflating: airs-master/airs-dataset/test-input/22528900_15.tiff
#   inflating: airs-master/airs-dataset/test-input/22829035_15.tiff
#   inflating: airs-master/airs-dataset/test-input/22978990_15.tiff
#   inflating: airs-master/airs-dataset/test-input/23128930_15.tiff
# ...

# %%
import os
os.chdir("image-output")
# !ls
# Out:
# output_img.tif

# %%
# !ls
# !python classify.py input_img.tiff output_img.tif
# Out:
# 2018-08-19 10:29:58.506457: initializing input data...
# 2018-08-19 10:29:58.592040: initializing model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:378: multi_class_head (from tensorflow.contrib.learn.python.learn.estimators.head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.contrib.estimator.*_head.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:1179: BaseEstimator.__init__ (from tensorflow.contrib.learn.python.learn.estimators.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please replace uses of any Estimator from tf.contrib.learn with an Estimator from tf.estimator.*
# ...

# %%
from google.colab import files


files.download('output_img.tif')
